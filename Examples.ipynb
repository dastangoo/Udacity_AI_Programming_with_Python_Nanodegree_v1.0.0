# %%
res = 3/4

# %%
res
# Out:
# 0.75

# %%
type(res)
# Out:
# float

# %%
res = 16/4

# %%
res
# Out:
# 4.0

# %%
type(res)
# Out:
# float

# %%
type(4)
# Out:
# int

# %%
type(4.3)
# Out:
# float

# %%
type(4.)
# Out:
# float

# %%
type(.1)
# Out:
# float

# %%
print(3 + 2.5)
# Out:
# 5.5

# %%
print(int(49.7))
# Out:
# 49

# %%
print(int(16/4))
# Out:
# 4

# %%
print(float(3520 + 3239))
# Out:
# 6759.0

# %%
print(0.1)
# Out:
# 0.1

# %%
print(0.1 + 0.1 + 0.1)
# Out:
# 0.30000000000000004
