# %%
print("hello")
# Out:
# hello

# %%
print('hello')
# Out:
# hello

# %%
welcome_message = "Hello, welcome to Udacity!"

# %%
print(welcome_message)
# Out:
# Hello, welcome to Udacity!

# %%
pet_hailbut = 'Why should I be tarred with the epithet "loony" merely because I have a pet hailbut?'

# %%
print(pet_hailbut)
# Out:
# Why should I be tarred with the epithet "loony" merely because I have a pet hailbut?

# %%
salesman = "I think you\'re an encyclopedia salesman"

# %%
print(salesman)
# Out:
# I think you're an encyclopedia salesman

# %%
first_word = "Hello"

# %%
second_word = "There"

# %%
print(first_word + second_word)
# Out:
# HelloThere

# %%
print(first_word, second_word)
# Out:
# Hello There

# %%
test = "string"

# %%
print("This is just for test %s" % test)
# Out:
# This is just for test string

# %%
print(f"This is just for test {test}")
# Out:
# This is just for test string

# %%
print("This is just for test {}".format(test))
# Out:
# This is just for test string

# %%
print(first_word + " " + second_word)
# Out:
# Hello There

# %%
word = "Hello"

# %%
print(word * 5)
# Out:
# HelloHelloHelloHelloHello

# %%
print(first_word / second_word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-ad7f95887784> in <module>
# ----> 1 print(first_word / second_word)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
udacity_length = len("Udacity")

# %%
print(udacity_length)
# Out:
# 7

# %%
first_word[0]
# Out:
# 'H'

# %%
first_word[1]
# Out:
# 'e'
