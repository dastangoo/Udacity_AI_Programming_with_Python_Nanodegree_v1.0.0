# %%
type(4)
# Out:
# int

# %%
type(4.3)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type("string")
# Out:
# str

# %%
count = int(4.0)

# %%
print(count)
# Out:
# 4

# %%
count
# Out:
# 4

# %%
print(type(count))
# Out:
# <class 'int'>

# %%
type(count)
# Out:
# int

# %%
house_number = 13

# %%
street_name = "The Crescent"

# %%
town_name = "Belmont"

# %%
print(type(house_number))
# Out:
# <class 'int'>

# %%
address = str(house_number) + " " + street_name + ", " + town_name

# %%
print(address)
# Out:
# 13 The Crescent, Belmont

# %%
grams = "35.0"

# %%
print(type(grams))
# Out:
# <class 'str'>

# %%
grams = float(grams)

# %%
print(type(grams))
# Out:
# <class 'float'>

# %%
"0" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-f3eee68b9620> in <module>
# ----> 1 "0" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
0 + "5"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-3dd32333af13> in <module>
# ----> 1 0 + "5"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
0 + 5
# Out:
# 5

# %%
"0" + "5"
# Out:
# '05'
