# %%
the_sun_is_up = True

# %%
the_sun_is_blue = False

# %%
x = 42 > 43

# %%
print(x)
# Out:
# False

# %%
type(42 > 43)
# Out:
# bool

# %%
age = 14

# %%
is_teen = age > 12 and age < 20

# %%
print(is_teen)
# Out:
# True
